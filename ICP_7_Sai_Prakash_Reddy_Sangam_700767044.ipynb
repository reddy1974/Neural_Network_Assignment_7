# %%
import numpy as np
from keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.constraints import max_norm
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical

# %%
np.random.seed(7)

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step

# %%
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# %%
from tensorflow.keras.utils import to_categorical

# Example usage
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
num_classes = y_test.shape[1]

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(32, 32, 3), padding='same', activation='relu', kernel_constraint=max_norm(3)))
model.add(Dropout(0.2))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', kernel_constraint=max_norm(3)))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
model.add(Flatten())
model.add(Dense(512, activation='relu', kernel_constraint=max_norm(3)))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# %%
sgd = SGD(learning_rate=0.01, momentum=0.9)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 32, 32, 32)        896
#
#  dropout_1 (Dropout)         (None, 32, 32, 32)        0
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d_1 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense (Dense)               (None, 512)               4194816
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 4210090 (16.06 MB)
# Trainable params: 4210090 (16.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
epochs = 5
batch_size = 32

history = model.fit(
    X_train, 
    y_train_encoded, 
    validation_data=(X_test, y_test_encoded), 
    epochs=epochs, 
    batch_size=batch_size
)
# Out:
# Epoch 1/5
# 1563/1563 [==============================] - 196s 125ms/step - loss: 0.8477 - accuracy: 0.7029 - val_loss: 0.8040 - val_accuracy: 0.7185
# Epoch 2/5
# 1563/1563 [==============================] - 200s 128ms/step - loss: 0.7861 - accuracy: 0.7237 - val_loss: 0.7587 - val_accuracy: 0.7414
# Epoch 3/5
# 1563/1563 [==============================] - 251s 160ms/step - loss: 0.7309 - accuracy: 0.7453 - val_loss: 0.7536 - val_accuracy: 0.7390
# Epoch 4/5
# 1563/1563 [==============================] - 282s 181ms/step - loss: 0.6894 - accuracy: 0.7587 - val_loss: 0.7116 - val_accuracy: 0.7563
# Epoch 5/5
# 1563/1563 [==============================] - 277s 177ms/step - loss: 0.6564 - accuracy: 0.7706 - val_loss: 0.7037 - val_accuracy: 0.7606

# %%
accuracy = history.history['val_accuracy'][-1] * 100
print("Accuracy: %.2f%%" % accuracy)
# Out:
# Accuracy: 76.06%

# %%
import numpy as np
from keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.constraints import max_norm
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical

# Fix random seed for reproducibility
np.random.seed(7)

# Load data
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# Normalize inputs from 0-255 to 0.0-1.0
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# One hot encode outputs
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
num_classes = y_test.shape[1]

# Create the model
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(32, 32, 3), padding='same', activation='relu', kernel_constraint=max_norm(3)))
model.add(Dropout(0.2))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', kernel_constraint=max_norm(3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same', kernel_constraint=max_norm(3)))
model.add(Dropout(0.2))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same', kernel_constraint=max_norm(3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same', kernel_constraint=max_norm(3)))
model.add(Dropout(0.2))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same', kernel_constraint=max_norm(3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(1024, activation='relu', kernel_constraint=max_norm(3)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu', kernel_constraint=max_norm(3)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

# Compile model
epochs = 5
learning_rate = 0.01
decay_rate = learning_rate / epochs
from keras.optimizers import SGD as LegacySGD
sgd = SGD(learning_rate=0.01, momentum=0.9)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
print(model.summary())

# Fit the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=32)

# Evaluate the model
accuracy = history.history['val_accuracy'][-1] * 100
print("Accuracy: %.2f%%" % accuracy)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_32 (Conv2D)          (None, 32, 32, 32)        896
#
#  dropout_31 (Dropout)        (None, 32, 32, 32)        0
#
#  conv2d_33 (Conv2D)          (None, 32, 32, 32)        9248
#
#  max_pooling2d_18 (MaxPooli  (None, 16, 16, 32)        0
#  ng2D)
#
#  conv2d_34 (Conv2D)          (None, 16, 16, 64)        18496
#
#  dropout_32 (Dropout)        (None, 16, 16, 64)        0
#
#  conv2d_35 (Conv2D)          (None, 16, 16, 64)        36928
#
#  max_pooling2d_19 (MaxPooli  (None, 8, 8, 64)          0
#  ng2D)
#
#  conv2d_36 (Conv2D)          (None, 8, 8, 128)         73856
#
#  dropout_33 (Dropout)        (None, 8, 8, 128)         0
#
#  conv2d_37 (Conv2D)          (None, 8, 8, 128)         147584
#
#  max_pooling2d_20 (MaxPooli  (None, 4, 4, 128)         0
#  ng2D)
#
#  flatten_8 (Flatten)         (None, 2048)              0
#
#  dropout_34 (Dropout)        (None, 2048)              0
#
#  dense_22 (Dense)            (None, 1024)              2098176
#
#  dropout_35 (Dropout)        (None, 1024)              0
#
#  dense_23 (Dense)            (None, 512)               524800
#
#  dropout_36 (Dropout)        (None, 512)               0
#
#  dense_24 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 2915114 (11.12 MB)
# Trainable params: 2915114 (11.12 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/5
# 1563/1563 [==============================] - 202s 128ms/step - loss: 1.8437 - accuracy: 0.3149 - val_loss: 1.5650 - val_accuracy: 0.4427
# Epoch 2/5
# 1563/1563 [==============================] - 196s 126ms/step - loss: 1.4153 - accuracy: 0.4829 - val_loss: 1.2381 - val_accuracy: 0.5442
# Epoch 3/5
# 1563/1563 [==============================] - 203s 130ms/step - loss: 1.2133 - accuracy: 0.5659 - val_loss: 1.0972 - val_accuracy: 0.6012
# Epoch 4/5
# 1563/1563 [==============================] - 192s 123ms/step - loss: 1.0508 - accuracy: 0.6291 - val_loss: 0.9611 - val_accuracy: 0.6637
# Epoch 5/5
# 1563/1563 [==============================] - 197s 126ms/step - loss: 0.9394 - accuracy: 0.6680 - val_loss: 0.9120 - val_accuracy: 0.6762
# Accuracy: 67.62%

# %%
predictions = model.predict(X_test[:4])
predicted_labels = np.argmax(predictions, axis=1)
actual_labels = np.argmax(y_test[:4], axis=1)
print("Predicted labels:", predicted_labels)
print("Actual labels:   ", actual_labels)
# Out:
# 1/1 [==============================] - 0s 63ms/step
# Predicted labels: [3 8 8 0]
# Actual labels:    [3 8 8 0]

# %%
import matplotlib.pyplot as plt

# Plot the training and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# Plot the training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='lower right')
plt.show()
